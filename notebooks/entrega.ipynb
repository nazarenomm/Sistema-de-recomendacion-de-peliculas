# %% [markdown]
# # Trabajo Final Integrador — Introducción al NLP
# ## Sistema de recomendación de películas basado en contenido
#
# Dado el corpus `mathigatti/spanish_imdb_synopsis` (~4.970 películas con sinopsis en español, *keywords*, género, año y director) y un conjunto de 14 perfiles de usuario simulados (historial de 5 películas + una *query* en lenguaje natural), el objetivo es generar para cada usuario una lista de **5 películas recomendadas**.
#
# A lo largo del notebook implementamos y comparamos **tres estrategias de representación**:
#
# 1. **Embeddings con *Sentence-Transformer*** — concatenamos query + historial en un único texto y lo proyectamos al espacio de embeddings.
# 2. **Embeddings promediados + LLM (Ollama)** — separamos query e historial, usamos un LLM para clasificar la intención de la query y combinamos ambas señales con un promedio ponderado dinámico.
# 3. **Topic Modeling con BERTopic** — representamos cada película y cada usuario por su distribución sobre tópicos latentes.

# %% [markdown]
# ## Instalaciones necesarias

# %%
# !pip install datasets
# !pip install sentence-transformers
# !pip install gensim
# !sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# !pip install ollama
# !ollama pull llama3.2
# !pip install bertopic
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.5.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.24.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.24.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.24.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.24.0->datasets) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.24.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.24.0->datasets) (0.1.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.5.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.10.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.18.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# zstd is already the newest version (1.4.8+dfsg-3build1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Requirement already satisfied: ollama in /usr/local/lib/python3.12/dist-packages (0.6.2)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from ollama) (2.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.4.2)

# %%
import pandas as pd
import re
import html
import numpy as np
from collections import Counter
import json as json_lib

import subprocess, time
import ollama

from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Carga de datasets

# %% [markdown]
# Traemos el dataset de sinopsis de peliculas de IMDb desde Hugging Face

# %%
df_pelis = pd.read_csv("https://raw.githubusercontent.com/nazarenomm/Sistema-de-recomendacion-de-peliculas/refs/heads/main/data/peliculas.csv")

# %% [markdown]
# Traemos el dataset proporcionado con la información de los usuarios y sus respectivas queries

# %%
usuarios = pd.read_csv("https://raw.githubusercontent.com/nazarenomm/Sistema-de-recomendacion-de-peliculas/refs/heads/main/data/usuarios.csv")

# %% [markdown]
# Visualizamos las queries

# %%
for texto in usuarios['query']:
    print(texto)
# Out:
# Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
# Busco algo basado en hechos reales sobre corrupción o poder político
# Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
# Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
# Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
# Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
# Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
# Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
# Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
# Algo que sea difícil de clasificar, con una lógica narrativa propia, no convencional
# No sé bien, algo que valga la pena ver un domingo a la noche, que enganche desde el principio
# Quiero algo distinto a lo de siempre, pero tampoco tan raro, con buenas actuaciones supongo
# Algo que pueda ver con amigos o solo, que no sea muy larga ni muy corta
# No tengo ganas de pensar mucho, pero tampoco quiero algo vacío, algo intermedio

# %% [markdown]
# ### Limpieza inicial y construcción del id
#
# Antes de procesar el texto resolvemos dos cuestiones del corpus crudo:
#
# - **Entidades HTML:** algunos campos vienen con secuencias como `&apos;` en lugar de los caracteres reales. Aplicamos `html.unescape` sobre todas las columnas de tipo texto.
# - **Identificador único:** el corpus no trae un `id`, así que agregamos uno a partir del índice.

# %%
df_pelis.iloc[83].keywords
# Out:
# 'escena sexual, relación hermano hermana, reference to guns n&apos; roses, comedia negra, white boy raps'

# %%
for col in df_pelis.columns:
    if df_pelis[col].dtype == 'object':  # Solo columnas string
        df_pelis[col] = df_pelis[col].apply(lambda x: html.unescape(str(x)) if pd.notna(x) else x)

# %%
df_pelis.iloc[83].keywords
# Out:
# "escena sexual, relación hermano hermana, reference to guns n' roses, comedia negra, white boy raps"

# %%
df_pelis["id"] = df_pelis.index + 1
df_pelis.head()
# Out:
#                                          description  \
# 0  Orin Boyd, un duro policía de una comisaría de...
# 1  Al llegar a un pequeño pueblo donde ha heredad...
# 2  Una mujer finge su muerte en un intento de esc...
# 3  Durante un memorial en la ciudad natal de su p...
# 4  Las pruebas nucleares francesas irradian a una...
#
#                                             keywords  \
# 0  vietnam war veteran, heroína, drogas, narcotra...
# 1    herencia, hostess, comedia negra, pueblo, magia
# 2  violencia doméstica, muerte fingida, borderlin...
# 3  manic pixie dream girl, publicidad, bad public...
# 4  monstruo gigante, iguana, militar, giant footp...
#
#                                genre    year                            name  \
# 0           acción, crimen, suspense  2001.0                  Herida abierta
# 1                    comedia, terror  1989.0  Elvira, reina de las tinieblas
# 2                    drama, suspense  1991.0        Durmiendo con su enemigo
# 3            comedia, drama, romance  2005.0                   Elizabethtown
# 4  acción, ciencia ficción, suspense  1998.0                        Godzilla
#
#              director  id
# 0  Andrzej Bartkowiak   1
# 1    James Signorelli   2
# 2        Joseph Ruben   3
# 3       Cameron Crowe   4
# 4     Roland Emmerich   5

# %% [markdown]
# ## Preprocesado
#
# Convertimos cada película en un **único texto representativo** que será la entrada de todos los modelos. Esta es una decisión central: qué información del corpus incluimos define qué puede "entender" el sistema por similitud.

# %% [markdown]
# ### Función de limpieza de texto
#
# Aplicamos un pipeline de limpieza: remover HTML, eliminación de caracteres extraños y espacios múltiples

# %%
def limpiar_texto(text):
    if not isinstance(text, str):
        return ''
    text = re.sub(r'<[^>]+>', ' ', text)        # remover HTML si hubiera
    text = re.sub(r'[^\w\s\.,;:!?áéíóúüñ-]', ' ', text)  # caracteres extraños
    text = re.sub(r'\s+', ' ', text)             # espacios múltiples
    return text.strip()

# %% [markdown]
# Unificamos las variables en un texto:
# + Nombre de la película
# + Sinopsis o descripción
# + Director
# + Año de estreno
# + Generos
# + Palabras clave

# %%
df_pelis["texto"] = (
    df_pelis["name"].apply(limpiar_texto) + ". "
    + df_pelis["description"].apply(limpiar_texto) + " "
    + df_pelis["director"].fillna('').apply(limpiar_texto) + ". "
    + df_pelis["year"].apply(lambda x: str(int(x)) if pd.notnull(x) else '') + ". "
    + df_pelis["genre"].apply(limpiar_texto) + ". "
    + df_pelis["keywords"].apply(limpiar_texto)
)

# %%
df_pelis.texto.iloc[0]
# Out:
# 'Herida abierta. Orin Boyd, un duro policía de una comisaría del centro de la ciudad, descubre una red de policías corruptos. Andrzej Bartkowiak. 2001. acción, crimen, suspense. vietnam war veteran, heroína, drogas, narcotraficante, corrupt cop'

# %% [markdown]
# #### El spanglish en ``genre`` y ``keywords``:
# El modelo multilingüe que usaremos maneja texto en múltiples idiomas, pero fue entrenado con documentos monolingües por separado, no necesariamente con mezcla de idiomas dentro del mismo string.
#
# No es un problema grave ya que el modelo es bastante robusto esto. Aún así vale la pena mencionar esta limitación del corpus.

# %% [markdown]
# ## Enfoque 1 - Embeddings con sentence transformer
#
# Primera estrategia de representación. Usamos un modelo `sentence-transformer` multilingüe para proyectar tanto las películas como los usuarios al **mismo espacio vectorial**, y recomendamos por **similitud coseno**.

# %% [markdown]
# ### Embedding de peliculas

# %% [markdown]
# Cargamos el modelo multilingüe

# %%
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:122: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %% [markdown]
# #### Calcular embedding de cada película

# %% [markdown]
# Usamos el modelo para calcular los embeddings de cada pelicula en nuestra base de datos usando e texto unificado definido anteriormente.

# %%
pelis_embeddings = model.encode(df_pelis['texto'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/156 [00:00<?, ?it/s]

# %% [markdown]
# Como los datasets de películas y embeddings se construyeron en el mismo orden, podemos unirlos directamente por índice.

# %%
df_pelis = df_pelis.reset_index(drop=True)

pelis_embeddings_df = pd.DataFrame(pelis_embeddings)
pelis_embeddings_df = pelis_embeddings_df.merge(
    df_pelis[['id', 'name']], 
    left_index=True, 
    right_index=True
)

# %%
pelis_embeddings_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.031084  0.032719 -0.272750  0.105669  0.088466  0.341037  0.109469
# 1 -0.007789  0.076889 -0.077062  0.274105 -0.079885 -0.025508  0.314847
# 2 -0.017430  0.006371 -0.100607  0.260501  0.053604  0.227207  0.040888
# 3  0.137272  0.015918  0.013975  0.060339 -0.133089  0.079739  0.129728
# 4 -0.165777  0.050897 -0.000996 -0.207756  0.106295 -0.271873 -0.016602
#
#           7         8         9  ...       376       377       378       379  \
# 0  0.170736  0.048048 -0.134747  ... -0.053232  0.032655 -0.199530 -0.102709
# 1  0.059361  0.081432  0.050591  ...  0.168026  0.220522 -0.022279 -0.104578
# 2 -0.065317  0.184578 -0.041667  ...  0.132501  0.318629 -0.022673  0.075589
# 3 -0.093552  0.063228  0.041110  ... -0.029802  0.355402  0.058575 -0.094542
# 4  0.089710  0.047141  0.133440  ... -0.091462 -0.023140 -0.099317  0.237066
#
#         380       381       382       383  id                            name
# 0  0.034748 -0.105462  0.243188  0.014966   1                  Herida abierta
# 1  0.325792 -0.082222 -0.040965 -0.080095   2  Elvira, reina de las tinieblas
# 2  0.229808  0.034454  0.114800 -0.044366   3        Durmiendo con su enemigo
# 3  0.238030  0.101194  0.021751 -0.007258   4                   Elizabethtown
# 4  0.205077 -0.302631  0.368318  0.098505   5                        Godzilla
#
# [5 rows x 386 columns]

# %% [markdown]
# Con este dataframe vamos a poder buscar los embedding por nombre de la pelicula o id

# %% [markdown]
# ### Embeddings de usuarios
#
# Para recomendar necesitamos representar a cada usuario en el **mismo espacio** que las películas. En este primer enfoque construimos el vector de usuario concatenando su *query* con las sinopsis de las 5 películas de su historial, y lo proyectamos con el mismo modelo.

# %% [markdown]
# Aplicamos la misma función de limpieza que usamos para las sinopsis. Como la data de usuarios rovista esta limpia no hace falta limpiarlos pero debería ser parte del pipeline operativo habitual.

# %%
# data_clean_users = pd.DataFrame(usuarios["query"].apply(limpiar_texto))

# %% [markdown]
# Debemos considerar que el modelo tiene limite de 512 tokens. Chequeamos que al pasar el texto ``query + texto unificado del historial`` no superemos este límite.

# %%
df_pelis["word_count"] = df_pelis["texto"].apply(lambda x: len(str(x).split()))

print("Cantidad maxima de palabras:")
print(df_pelis["word_count"].max())

print("Mediana de palabras:")
print(df_pelis["word_count"].median())
# Out:
# Cantidad maxima de palabras:
# 79
# Mediana de palabras:
# 45.0

# %%
usuarios["query_word_count"] = usuarios["query"].apply(lambda x: len(str(x).split()))

print("Cantidad maxima de palabras en queries de usuarios:")
print(usuarios["query_word_count"].max())

print("Mediana de palabras en queries de usuarios:")
print(usuarios["query_word_count"].median())
# Out:
# Cantidad maxima de palabras en queries de usuarios:
# 19
# Mediana de palabras en queries de usuarios:
# 15.5

# %% [markdown]
# Igualmente hay que considerar que las queries provistas son cortas, podrían haber más largas en un futuro. Para solucionar esto se podría implementar un límite de palabras para la query de usuario.
# Si suponemos un limite de, por ejemplo, $30$ palabras y que, en promedio, cada palabra se tokeniza en $1.5$-$2$ tokens. Entonces cada texto de usuario tendría:
#
# ``44 palabras × 5 películas + query (max 30 palabras, por ejemplo) ≈ 250 palabras ≈ 375-500 tokens``
#
# Y estaría por debajo del límite.

# %% [markdown]
# #### Calcular el embedding de cada usuario
#
# `build_user_text` arma, para cada usuario, un único texto que concatena la **query** con el **texto de las 5 películas del historial**. Ese texto se proyecta con el mismo modelo, de modo que query e historial pesan juntos dentro de un solo vector.

# %%
def build_user_text(row, df_pelis):
    # Query del usuario
    partes = [row['query']]
    
    # Descripciones de las 5 películas del historial
    for col in ['pelicula_1','pelicula_2','pelicula_3','pelicula_4','pelicula_5']:
        nombre = row[col]
        match = df_pelis[df_pelis['name'] == nombre]['texto']
        if len(match):
            partes.append(match.values[0])
    
    return ' '.join(partes)

# %%
user_texts = usuarios.apply(lambda r: build_user_text(r, df_pelis), axis=1).tolist()

# %% [markdown]
# Con esos textos unificados y el transformer calculamos el embedding de cada usuario.

# %%
user_embeddings = model.encode(user_texts, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
user_embeddings_df = pd.DataFrame(user_embeddings)
user_embeddings_df = user_embeddings_df.merge(usuarios[['id']], left_index=True, right_index=True)
user_embeddings_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.238107 -0.128500 -0.207465  0.260500  0.247655  0.290276  0.095238
# 1 -0.249082  0.191250 -0.289829  0.216814  0.266727  0.115557  0.088643
# 2 -0.010083 -0.286078 -0.028388 -0.073591  0.070636  0.379458  0.180789
# 3 -0.135121 -0.022123 -0.174233 -0.013320  0.024583 -0.171468  0.109334
# 4 -0.022892  0.008990 -0.241990  0.069403  0.142337  0.157824  0.238181
#
#           7         8         9  ...       375       376       377       378  \
# 0 -0.093639  0.200505  0.013914  ...  0.297109  0.074182  0.340460 -0.116549
# 1 -0.020128  0.025625  0.020821  ... -0.078047 -0.033263  0.171906 -0.238212
# 2  0.056127  0.217427 -0.043305  ...  0.053136  0.069376  0.004023 -0.328375
# 3  0.055659  0.042445  0.104168  ... -0.050089 -0.095498  0.186530 -0.198212
# 4 -0.189650  0.251596  0.146036  ...  0.137518  0.138679  0.324707  0.010308
#
#         379       380       381       382       383   id
# 0  0.221070  0.159515 -0.142231  0.079386 -0.026740  U01
# 1 -0.107697  0.169403 -0.052990 -0.165263 -0.162586  U02
# 2 -0.023175  0.125202  0.085754  0.105665  0.007408  U03
# 3  0.121175  0.162361  0.030514 -0.036455  0.011859  U04
# 4  0.202955  0.194683 -0.085762 -0.002339 -0.013053  U05
#
# [5 rows x 385 columns]

# %% [markdown]
# ### Recomendaciones y evaluación
#
#
# Con los vectores de usuarios y películas calculamos la **similitud coseno** entre cada usuario y todas las películas, filtramos las ya vistas (poniendo su score en `-inf`) y nos quedamos con el **top-5**.

# %% [markdown]
# Para validar necesitamos algún tipo de etiqueta objetivo. Como no existe un listado de "películas correctas", usamos el **género** como aproximación de relevancia.
#
# Primero miramos qué géneros existen en el corpus y su frecuencia, para entender con qué vocabulario de géneros contamos.

# %%
contador_generos = Counter()

for generos_str in df_pelis['genre']:
    generos_str = generos_str.strip('[]')
    generos_list = [g.strip() for g in generos_str.split(',')]
    contador_generos.update(generos_list)

# convertir a DataFrame
df_generos = pd.DataFrame(
    list(contador_generos.items()),
    columns=['Género', 'Frecuencia']
).sort_values('Frecuencia', ascending=False).reset_index(drop=True)

print(df_generos)
# Out:
#              Género  Frecuencia
# 0             drama        2649
# 1           comedia        1932
# 2            acción        1222
# 3            crimen        1083
# 4          aventura         944
# 5           romance         856
# 6          suspense         740
# 7            terror         532
# 8          misterio         479
# 9          fantasía         412
# 10         familiar         361
# 11        animación         351
# 12  ciencia ficción         347
# 13        biografía         268
# 14         historia         151
# 15           música         148
# 16          deporte         113
# 17           bélico         103
# 18       documental          49
# 19          musical          37
# 20            corto          32
# 21        del oeste          22
# 22          reality          13
# 23         concurso           7
# 24         tertulia           4
# 25         noticias           2

# %% [markdown]
# Miramos los generos del historial de cada usuario

# %%
resultados = []

for idx, usuario in usuarios.iterrows():
    usuario_id = usuario['id']
    generos_usuario = Counter()
    
    for col in ['pelicula_1', 'pelicula_2', 'pelicula_3', 'pelicula_4', 'pelicula_5']:
        nombre_pelicula = usuario[col]
        pelicula = df_pelis[df_pelis['name'] == nombre_pelicula]
        
        if not pelicula.empty:
            generos_str = pelicula.iloc[0]['genre']
            generos_str = generos_str.strip('[]')
            generos_list = [g.strip() for g in generos_str.split(',')]
            generos_usuario.update(generos_list)
    
    # obtener top 3-4 géneros por usuario
    top_generos = generos_usuario.most_common(5)
    generos_str = ', '.join([f"{g} ({f})" for g, f in top_generos])
    
    resultados.append({
        'Usuario': usuario_id,
        'Géneros historial': generos_str
    })

conteo_hist = pd.DataFrame(resultados)
print(conteo_hist.to_string())
# Out:
#    Usuario                                                        Géneros historial
# 0      U01  suspense (4), drama (3), misterio (3), romance (1), ciencia ficción (1)
# 1      U02         drama (5), biografía (3), crimen (3), historia (1), misterio (1)
# 2      U03                                      comedia (5), romance (5), drama (3)
# 3      U04    ciencia ficción (5), acción (3), drama (2), suspense (2), romance (1)
# 4      U05         animación (5), aventura (4), drama (2), acción (2), familiar (1)
# 5      U06             crimen (5), drama (3), comedia (2), acción (1), misterio (1)
# 6      U07              drama (4), música (3), comedia (3), romance (2), crimen (1)
# 7      U08          acción (5), aventura (3), crimen (2), suspense (2), comedia (1)
# 8      U09          drama (5), comedia (3), romance (2), aventura (1), fantasía (1)
# 9      U10           drama (5), comedia (2), crimen (2), fantasía (1), suspense (1)
# 10     U11           drama (2), animación (1), aventura (1), acción (1), crimen (1)
# 11     U12                        comedia (1), romance (1), drama (1), historia (1)
# 12     U13            drama (4), acción (2), romance (1), aventura (1), comedia (1)
# 13     U14    comedia (2), drama (2), acción (1), aventura (1), ciencia ficción (1)

# %% [markdown]
# Y las queries de cada uno

# %%
for i in range(len(usuarios)):
    print(f"U{i+1}: " + usuarios["query"].iloc[i])
# Out:
# U1: Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
# U2: Busco algo basado en hechos reales sobre corrupción o poder político
# U3: Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
# U4: Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
# U5: Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
# U6: Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
# U7: Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
# U8: Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
# U9: Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
# U10: Algo que sea difícil de clasificar, con una lógica narrativa propia, no convencional
# U11: No sé bien, algo que valga la pena ver un domingo a la noche, que enganche desde el principio
# U12: Quiero algo distinto a lo de siempre, pero tampoco tan raro, con buenas actuaciones supongo
# U13: Algo que pueda ver con amigos o solo, que no sea muy larga ni muy corta
# U14: No tengo ganas de pensar mucho, pero tampoco quiero algo vacío, algo intermedio

# %% [markdown]
# A partir de los géneros del historial y de lo que pide cada query, definimos **a ojo** tres géneros esperados para cada usuario. Esto solo es posible para los **9 perfiles "definidos"** (preferencias claras y consistentes); los usuarios ambiguos (U10–U14) no se pueden etiquetar de forma confiable, así que la evaluación cuantitativa se restringe a esos 9.
#
# Con estas etiquetas calculamos, para cada usuario:
# - **Recall (géneros):** proporción de géneros esperados que aparecen en el top-5.
# - **Precision (películas):** proporción de películas del top-5 que tienen al menos un género esperado.
# - **F1:** media armónica de ambas.

# %%
etiquetas_a_ojo_def = [
    ["suspense", "terror", "drama"],
    ["crimen", "biografía", "historia"],
    ["comedia", "romance", "drama"],
    ["acción", "ciencia ficción", "suspense"],
    ["animación", "drama", "aventura"],
    ["crimen", "acción", "comedia"],
    ["música", "drama", "comedia"],
    ["acción", "crimen", "aventura"],
    ["drama", "romance", "comedia"],
    # el U10 es ambiguo, la etiqueta debe estar mal
    # los demás usuarios son ambiguos
]

# %% [markdown]
# Ahora calculamos la similitud coseno entre los embeddings de usuarios y los de las peliculas, elegimos los 5 más similares y mostramos los resultados para todos los usuarios (perfiles ambiguos incluídos para análisis)

# %%
scores = cosine_similarity(user_embeddings, pelis_embeddings)

# Filtrar películas del historial seteando su score a -inf
hist_cols = ['pelicula_1', 'pelicula_2', 'pelicula_3', 'pelicula_4', 'pelicula_5']
scores_filtrado = scores.copy()

for i, row in usuarios.iterrows():
    for col in hist_cols:
        nombre = row[col]
        match = df_pelis[df_pelis['name'] == nombre].index
        if len(match):
            scores_filtrado[i, match[0]] = -np.inf

# Top-5 por usuario
top5_indices = scores_filtrado.argsort(axis=1)[:, -5:][:, ::-1]

# Ver resultados
for i, row in usuarios.iterrows():
    print(f"\n{row['nombre']} ({row['tipo_perfil']})")
    print(f"Query: {row['query']}")
    for idx in top5_indices[i]:
        pelicula = df_pelis.iloc[idx]
        print(f"  {pelicula['name']} ({int(pelicula['year']) if not pd.isna(pelicula['year']) else 'N/A'}) — {scores_filtrado[i, idx]:.4f}")
# Out:
# Valentina (definido)
# Query: Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
#   Tránsito (2006) — 0.7501
#   La mano que mece la cuna (1992) — 0.6389
#   Begotten (1991) — 0.6329
#   Truly Madly Deeply (1992) — 0.6250
#   La novia cadáver (2005) — 0.6224
#
# Rodrigo (definido)
# Query: Busco algo basado en hechos reales sobre corrupción o poder político
#   Historia de un soldado (1985) — 0.5787
#   Monster's Ball (2002) — 0.5781
#   Vida de este chico (1994) — 0.5734
#   Una árida estación blanca (1989) — 0.5712
#   Gorilas en la niebla (1989) — 0.5606
#
# Camila (definido)
# Query: Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
#   Ahora los padres son ellos (2010) — 0.6998
#   Mira quién habla también (1991) — 0.6465
#   Más allá del odio (2005) — 0.6451
#   Swingers (1997) — 0.6429
#   La familia Addams (1992) — 0.6395
#
# Tomás (definido)
# Query: Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
#   La red (1995) — 0.7286
#   Pulse (Conexión) (2007) — 0.6907
#   El cortador de césped (1992) — 0.6874
#   Nivel 13 (1999) — 0.6854
#   Proyecto Brainstorm (1983) — 0.6724
#
# Lucía (definido)
# Query: Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
#   Tránsito (2006) — 0.6831
#   Begotten (1991) — 0.6447
#   Durmiendo con su enemigo (1991) — 0.6119
#   La mano que mece la cuna (1992) — 0.6030
#   Crónica de un engaño (2010) — 0.5960
#
# Martín (definido)
# Query: Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
#   Como pez en el agua (1998) — 0.6527
#   El negociador (1997) — 0.6349
#   Persecución extrema (2007) — 0.6321
#   Albino Alligator (1997) — 0.6173
#   ¡Que te calles! (2004) — 0.6141
#
# Sofía (definido)
# Query: Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
#   Ray (2005) — 0.6205
#   Hedwig and the Angry Inch (2001) — 0.6091
#   La diva (1981) — 0.6001
#   Miedo y asco en Las Vegas (1999) — 0.5986
#   El corazón del ángel (1987) — 0.5918
#
# Diego (definido)
# Query: Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
#   Hollywood: Departamento de homicidios (2003) — 0.7927
#   Más fuerte que el odio (1988) — 0.7364
#   The Fast and the Furious (A todo gas) (2001) — 0.7315
#   Max Payne (2008) — 0.7294
#   L.A. Confidential (1997) — 0.7011
#
# Elena (definido)
# Query: Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
#   Brothers (Hermanos) (2010) — 0.5649
#   Algo en común (2005) — 0.5644
#   El turista accidental (1989) — 0.5599
#   Todos están bien (2010) — 0.5580
#   La vida de Pi (2012) — 0.5513
#
# Facundo (definido)
# Query: Algo que sea difícil de clasificar, con una lógica narrativa propia, no convencional
#   Apocalipsis (1994) — 0.6644
#   Seul contre tous (1999) — 0.6231
#   Atando cabos (2002) — 0.6182
#   La última casa a la izquierda (2009) — 0.6170
#   Aún sé lo que hicisteis el último verano (1999) — 0.6110
#
# Julián (ambiguo)
# Query: No sé bien, algo que valga la pena ver un domingo a la noche, que enganche desde el principio
#   Prince of Persia: Las arenas del tiempo (2010) — 0.6313
#   La bella y la bestia (1992) — 0.6214
#   La princesa cisne (1995) — 0.6003
#   El emperador y sus locuras (2001) — 0.5967
#   Salvaje (The Wild) (2006) — 0.5869
#
# Mariana (ambiguo)
# Query: Quiero algo distinto a lo de siempre, pero tampoco tan raro, con buenas actuaciones supongo
#   Juana de Arco de Luc Besson (2000) — 0.6266
#   El marido de la peluquera (1990) — 0.6225
#   Ángel (2007) — 0.6124
#   Belleza robada (1996) — 0.6079
#   El juego de Ripley (2003) — 0.6034
#
# Nicolás (ambiguo)
# Query: Algo que pueda ver con amigos o solo, que no sea muy larga ni muy corta
#   Titanic - La película animada (2000) — 0.6699
#   Buscando a Eva (1999) — 0.6492
#   Pearl Harbor (2001) — 0.6022
#   La hoguera de las vanidades (1990) — 0.5930
#   Matador (1986) — 0.5881
#
# Paula (ambiguo)
# Query: No tengo ganas de pensar mucho, pero tampoco quiero algo vacío, algo intermedio
#   Sabrina (y sus amores) (1996) — 0.6765
#   Doble cuerpo (1985) — 0.6380
#   La desaparición de Embry (2004) — 0.6327
#   Fallen Angels (Ángeles caídos) (1995) — 0.6289
#   Luz de luna (1986) — 0.6278

# %% [markdown]
# A simple vista el sistema esta lejos de ser perfecto:
# + Nicolás (ambiguo) pide una película que no sea muy larga y se le recomienda Titanic que dura 3 horas y media.
# + Varios mencionan en sus queries características del film que no suelen estar en las variables dadas en el corpus, pero sí podrían estar presentes en las reseñas de las películas, por ejemplo: "que enganche desde el principio", "lógica narrativa propia" o "con buenas actuaciones".
# + Mariana (ambiguo) pide algo **distinto** a lo de siempre pero el sistema siempre busca similitud con su historial, además su query no aporta información propia.
#
# Para solucionar algunos de estos problemas necesitariamos más información sobre las películas, como su duración o el resumen de reseñas que muestra imdb en su web.
# Para solucionar las queries sin peso propio pero que refieren al historial vamos a explorar calcular los embeddings de usuario como un promedio ponderado de su query y su historial. Esto lo veremos en el próximo enfoque.

# %% [markdown]
# Corremos la evaluación planteada anteriormente sobre los usuarios con perfiles definidos.

# %%
resultados_eval = []

for user_idx, row in usuarios.head(9).iterrows():
    print(f"\n{'='*70}")
    print(f"{row['nombre']} ({row['tipo_perfil']})")
    print(f"Query: {row['query']}")
    generos_esperados = set(etiquetas_a_ojo_def[user_idx])
    print(f"Géneros Esperados: {', '.join(generos_esperados)}")
    print(f"{'='*70}")
    
    generos_recomendados = Counter()
    peliculas_buenas = 0  # con al menos 1 género esperado
    peliculas_malas = []  # sin ningún género esperado
    
    print("\nTop-5 Recomendaciones:")
    for rank, idx in enumerate(top5_indices[user_idx], 1):
        pelicula = df_pelis.iloc[idx]
        score = scores[user_idx, idx]
        
        # Extraer géneros
        generos_str = pelicula['genre'].strip('[]')
        generos_list = [g.strip() for g in generos_str.split(',')]
        generos_pelicula = set(generos_list)
        generos_recomendados.update(generos_list)
        
        # ¿Tiene algún género esperado?
        es_buena = bool(generos_pelicula & generos_esperados)
        if es_buena:
            peliculas_buenas += 1
            marker = "✓"
        else:
            peliculas_malas.append(pelicula['name'])
            marker = "✗"
        
        print(f"  {rank}. [{marker}] {pelicula['name']} ({int(pelicula['year']) if not pd.isna(pelicula['year']) else 'N/A'}) — {score:.4f}")
        print(f"     Géneros: {', '.join(generos_list)}")
    
    # Conteo de géneros
    print(f"\nConteo de Géneros en Recomendaciones:")
    for genero, freq in generos_recomendados.most_common():
        print(f"  {genero}: {freq}")
    
    # Métricas
    generos_capturados = set(generos_recomendados.keys())
    recall = len(generos_capturados & generos_esperados) / len(generos_esperados)
    precision = peliculas_buenas / 5  # top-5
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    print(f"\nMÉTRICAS:")
    print(f"  Recall (géneros):     {recall:.1%}  ({len(generos_capturados & generos_esperados)}/{len(generos_esperados)})")
    print(f"  Precision (películas): {precision:.1%}  ({peliculas_buenas}/5)")
    print(f"  F1-Score:            {f1:.1%}")
    
    if peliculas_malas:
        print(f"\nPelículas problemáticas (sin géneros esperados):")
        for pelicula in peliculas_malas:
            print(f"    - {pelicula}")
    
    resultados_eval.append({
        'Usuario': row['nombre'],
        'Recall': recall,
        'Precision': precision,
        'F1': f1,
        'Películas Malas': len(peliculas_malas)
    })

# Resumen
print(f"\n\n{'='*70}")
print("RESUMEN DE EVALUACIÓN")
print(f"{'='*70}")
df_eval = pd.DataFrame(resultados_eval)
df_eval.to_csv("evaluacion_transformer.csv", index=False)
print(df_eval.to_string(index=False))
print(f"\nPromedios:")
print(f"  Recall:    {df_eval['Recall'].mean():.1%}")
print(f"  Precision: {df_eval['Precision'].mean():.1%}")
print(f"  F1-Score:  {df_eval['F1'].mean():.1%}")
# Out:
# ======================================================================
# Valentina (definido)
# Query: Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
# Géneros Esperados: suspense, drama, terror
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Tránsito (2006) — 0.7501
#      Géneros: drama, misterio, suspense
#   2. [✓] La mano que mece la cuna (1992) — 0.6389
#      Géneros: drama, suspense
#   3. [✓] Begotten (1991) — 0.6329
#      Géneros: fantasía, terror
#   4. [✓] Truly Madly Deeply (1992) — 0.6250
#      Géneros: comedia, drama, fantasía
#   5. [✓] La novia cadáver (2005) — 0.6224
#      Géneros: animación, drama, familiar
#
# Conteo de Géneros en Recomendaciones:
#   drama: 4
#   suspense: 2
#   fantasía: 2
#   misterio: 1
#   terror: 1
#   comedia: 1
#   animación: 1
#   familiar: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Rodrigo (definido)
# Query: Busco algo basado en hechos reales sobre corrupción o poder político
# Géneros Esperados: biografía, historia, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Historia de un soldado (1985) — 0.5787
#      Géneros: crimen, drama, misterio
#   2. [✗] Monster's Ball (2002) — 0.5781
#      Géneros: drama, romance
#   3. [✓] Vida de este chico (1994) — 0.5734
#      Géneros: biografía, drama
#   4. [✗] Una árida estación blanca (1989) — 0.5712
#      Géneros: drama, suspense
#   5. [✓] Gorilas en la niebla (1989) — 0.5606
#      Géneros: biografía, drama
#
# Conteo de Géneros en Recomendaciones:
#   drama: 5
#   biografía: 2
#   crimen: 1
#   misterio: 1
#   romance: 1
#   suspense: 1
#
# MÉTRICAS:
#   Recall (géneros):     66.7%  (2/3)
#   Precision (películas): 60.0%  (3/5)
#   F1-Score:            63.2%
#
# Películas problemáticas (sin géneros esperados):
#     - Monster's Ball
#     - Una árida estación blanca
#
# ======================================================================
# Camila (definido)
# Query: Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
# Géneros Esperados: romance, drama, comedia
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Ahora los padres son ellos (2010) — 0.6998
#      Géneros: comedia, romance
#   2. [✓] Mira quién habla también (1991) — 0.6465
#      Géneros: comedia, familiar, romance
#   3. [✓] Más allá del odio (2005) — 0.6451
#      Géneros: comedia, drama
#   4. [✓] Swingers (1997) — 0.6429
#      Géneros: comedia, drama
#   5. [✓] La familia Addams (1992) — 0.6395
#      Géneros: comedia, fantasía
#
# Conteo de Géneros en Recomendaciones:
#   comedia: 5
#   romance: 2
#   drama: 2
#   familiar: 1
#   fantasía: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Tomás (definido)
# Query: Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
# Géneros Esperados: ciencia ficción, suspense, acción
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] La red (1995) — 0.7286
#      Géneros: acción, crimen, drama
#   2. [✓] Pulse (Conexión) (2007) — 0.6907
#      Géneros: terror, ciencia ficción, suspense
#   3. [✓] El cortador de césped (1992) — 0.6874
#      Géneros: terror, ciencia ficción
#   4. [✓] Nivel 13 (1999) — 0.6854
#      Géneros: misterio, ciencia ficción, suspense
#   5. [✓] Proyecto Brainstorm (1983) — 0.6724
#      Géneros: ciencia ficción, suspense
#
# Conteo de Géneros en Recomendaciones:
#   ciencia ficción: 4
#   suspense: 3
#   terror: 2
#   acción: 1
#   crimen: 1
#   drama: 1
#   misterio: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Lucía (definido)
# Query: Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
# Géneros Esperados: aventura, animación, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Tránsito (2006) — 0.6831
#      Géneros: drama, misterio, suspense
#   2. [✗] Begotten (1991) — 0.6447
#      Géneros: fantasía, terror
#   3. [✓] Durmiendo con su enemigo (1991) — 0.6119
#      Géneros: drama, suspense
#   4. [✓] La mano que mece la cuna (1992) — 0.6030
#      Géneros: drama, suspense
#   5. [✓] Crónica de un engaño (2010) — 0.5960
#      Géneros: drama, misterio, suspense
#
# Conteo de Géneros en Recomendaciones:
#   drama: 4
#   suspense: 4
#   misterio: 2
#   fantasía: 1
#   terror: 1
#
# MÉTRICAS:
#   Recall (géneros):     33.3%  (1/3)
#   Precision (películas): 80.0%  (4/5)
#   F1-Score:            47.1%
#
# Películas problemáticas (sin géneros esperados):
#     - Begotten
#
# ======================================================================
# Martín (definido)
# Query: Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
# Géneros Esperados: comedia, acción, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Como pez en el agua (1998) — 0.6527
#      Géneros: comedia, crimen, romance
#   2. [✓] El negociador (1997) — 0.6349
#      Géneros: acción, comedia, crimen
#   3. [✓] Persecución extrema (2007) — 0.6321
#      Géneros: acción, comedia, drama
#   4. [✓] Albino Alligator (1997) — 0.6173
#      Géneros: crimen, drama, suspense
#   5. [✓] ¡Que te calles! (2004) — 0.6141
#      Géneros: comedia, crimen
#
# Conteo de Géneros en Recomendaciones:
#   comedia: 4
#   crimen: 4
#   acción: 2
#   drama: 2
#   romance: 1
#   suspense: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Sofía (definido)
# Query: Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
# Géneros Esperados: comedia, música, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Ray (2005) — 0.6205
#      Géneros: biografía, drama, música
#   2. [✓] Hedwig and the Angry Inch (2001) — 0.6091
#      Géneros: comedia, drama, música
#   3. [✓] La diva (1981) — 0.6001
#      Géneros: comedia, crimen, música
#   4. [✓] Miedo y asco en Las Vegas (1999) — 0.5986
#      Géneros: aventura, comedia, drama
#   5. [✗] El corazón del ángel (1987) — 0.5918
#      Géneros: terror, misterio, suspense
#
# Conteo de Géneros en Recomendaciones:
#   drama: 3
#   música: 3
#   comedia: 3
#   biografía: 1
#   crimen: 1
#   aventura: 1
#   terror: 1
#   misterio: 1
#   suspense: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 80.0%  (4/5)
#   F1-Score:            88.9%
#
# Películas problemáticas (sin géneros esperados):
#     - El corazón del ángel
#
# ======================================================================
# Diego (definido)
# Query: Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
# Géneros Esperados: aventura, acción, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Hollywood: Departamento de homicidios (2003) — 0.7927
#      Géneros: acción, comedia, crimen
#   2. [✓] Más fuerte que el odio (1988) — 0.7364
#      Géneros: acción, crimen, misterio
#   3. [✓] The Fast and the Furious (A todo gas) (2001) — 0.7315
#      Géneros: acción, crimen, suspense
#   4. [✓] Max Payne (2008) — 0.7294
#      Géneros: acción, aventura, crimen
#   5. [✓] L.A. Confidential (1997) — 0.7011
#      Géneros: crimen, drama, misterio
#
# Conteo de Géneros en Recomendaciones:
#   crimen: 5
#   acción: 4
#   misterio: 2
#   comedia: 1
#   suspense: 1
#   aventura: 1
#   drama: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Elena (definido)
# Query: Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
# Géneros Esperados: romance, comedia, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Brothers (Hermanos) (2010) — 0.5649
#      Géneros: drama, suspense, bélico
#   2. [✓] Algo en común (2005) — 0.5644
#      Géneros: comedia, drama, romance
#   3. [✓] El turista accidental (1989) — 0.5599
#      Géneros: drama, romance
#   4. [✓] Todos están bien (2010) — 0.5580
#      Géneros: aventura, drama
#   5. [✓] La vida de Pi (2012) — 0.5513
#      Géneros: aventura, drama, fantasía
#
# Conteo de Géneros en Recomendaciones:
#   drama: 5
#   romance: 2
#   aventura: 2
#   suspense: 1
#   bélico: 1
#   comedia: 1
#   fantasía: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
#
# ======================================================================
# RESUMEN DE EVALUACIÓN
# ======================================================================
#   Usuario   Recall  Precision       F1  Películas Malas
# Valentina 1.000000        1.0 1.000000                0
#   Rodrigo 0.666667        0.6 0.631579                2
#    Camila 1.000000        1.0 1.000000                0
#     Tomás 1.000000        1.0 1.000000                0
#     Lucía 0.333333        0.8 0.470588                1
#    Martín 1.000000        1.0 1.000000                0
#     Sofía 1.000000        0.8 0.888889                1
#     Diego 1.000000        1.0 1.000000                0
#     Elena 1.000000        1.0 1.000000                0
#
# Promedios:
#   Recall:    88.9%
#   Precision: 91.1%
#   F1-Score:  88.8%

# %% [markdown]
# + Valentina: A pesar de que las métricas parecen buenas, ninguna de las peliculas recomendadas cumple al 100% con la query. Esto puede ser porque la película que busca (probablemente "El hombre invisible") no está en la base de datos. Las recomendaciones que están más cerca de cumplir:
#     + La Mano Que Mece La Cuna (1992): una mujer enfrenta una amenaza de alguien cercano, su niñera.
#     + Truly Madly Deeply (1992): una mujer protagonista que es visitada por alguien cercano e invisible, el fantasma de su marido.
#
# + Rodrigo: F1 del 63.2%. Las películas que cumplen en parte con la query pueden ser:
#     +  Historia de un soldado (1985): no está basada en hechos reales pero, viendo la descripción, puede tratar sobre corrupción y poder político.
#     + Una árida estación blanca (1989): basada en hechos reales y trata sobre corrupción en la policía.
#
# + Camila: A pesar de las métricas del 100% ninguna película cumple con la consigna de una relación que empiece de forma ridicula o accidental. Esto puede ser porque no hay tal pelicula o porque no se suele mencionar en la sinopsis. El 100% en las métricas se da porque menciona explícitamente que quiere ver una comedia y su historial es consistente con esto.
#
# Con los demás usuarios siguen ocurriendo cosas similares. Con esto queremos dejar en claro que las métricas calculadas no son para nada confiables a la hora de evaluar el sistema ya que hay varios usuarios con métricas perfectas pero a los que se les recomiendan peliculas que no cumplen con sus requisitos.

# %% [markdown]
# ## Enfoque 2 - Embeddings promediados + LLM
#
# El Enfoque 1 mete query e historial en un mismo texto y no permite **regular el peso** de cada señal. Acá las separamos y las combinamos con un **promedio ponderado**, donde los pesos los decide la **intención de la query**.
#
# Para detectar esa intención usamos un LLM local (`llama3.2` vía Ollama) que clasifica cada query en una de tres categorías, y según la categoría:
# - damos más peso a la **query** o al **historial**, y elegimos las películas **más** o **menos** similares (para queries que piden "algo distinto").

# %% [markdown]
# **Pipeline del enfoque:**
#
# 1. Calcular el embedding de cada **query**.
# 2. Calcular el embedding del **historial** (promedio de los embeddings de las 5 películas vistas).
# 3. Clasificar la intención de la query con **Ollama**.
# 4. Combinar query e historial con un **promedio ponderado** según esa clasificación, y recomendar.

# %%
queries_embeddings = model.encode(usuarios['query'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
def get_all_historial_embeddings(usuarios_df, pelis_embeddings_df):
    all_embeddings = []
    
    for _, usuario_row in usuarios_df.iterrows():
        historial_embeddings = []
        
        for col in ['pelicula_1','pelicula_2','pelicula_3','pelicula_4','pelicula_5']:
            nombre = usuario_row[col]
            peli_emb = pelis_embeddings_df[pelis_embeddings_df['name'] == nombre]
            if not peli_emb.empty:
                historial_embeddings.append(peli_emb.drop(columns=['id', 'name']).values[0])
            else:
                print(f"Película '{nombre}' no encontrada.")
        
        embedding_promedio = np.mean(historial_embeddings, axis=0)
        all_embeddings.append(embedding_promedio)
    
    return np.array(all_embeddings)

# %%
historial_embeddings = get_all_historial_embeddings(usuarios, pelis_embeddings_df)
# Out:
# Película 'Rec' no encontrada.
# Película 'El secreto de sus ojos' no encontrada.
# Película 'El exorcista' no encontrada.
# Película 'Intocable' no encontrada.
# Película 'Una mente brillante' no encontrada.
# Película 'Paddington' no encontrada.

# %% [markdown]
# Cuando no encontramos una película en nuestra base de datos, simplemente no la contamos en el cálculo del embedding del historial

# %% [markdown]
# ### Configuración de Ollama
#
# Iniciamos el servidor de Ollama en background y descargamos el modelo a usar.

# %%
subprocess.Popen(['ollama', 'serve'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(3)
print("Servidor iniciado")
# Out:
# Servidor iniciado

# %% [markdown]
# Usamos Ollama (`llama3.2`) para clasificar cada query en **3 categorías**, cada una con su estrategia de combinación:
#
# 1. **`normal`** — query específica que no apela al historial → más peso a la query (`[0.7, 0.3]`) y top-5 más similares.
# 2. **`historial_positivo`** — el usuario quiere "lo de siempre" o la query es tan vaga que el historial es la mejor guía → más peso al historial (`[0.1, 0.9]`) y top-5 más similares.
# 3. **`historial_negativo`** — el usuario pide algo **distinto** a lo habitual → más peso al historial pero eligiendo las **menos** similares (`bottom-5`).
#
# El prompt fija la salida en JSON y usa `temperature=0.1` con `seed` fijo para que la clasificación sea reproducible.

# %%
# Mapeo fijo de categoría → parámetros
CATEGORIA_PARAMS = {
    'normal':                    {'weights': [0.7, 0.3], 'direction': 'top-5'},
    'historial_positivo':        {'weights': [0.1, 0.9], 'direction': 'top-5'},
    'historial_negativo':        {'weights': [0.1, 0.9], 'direction': 'bottom-5'},
}

def procesar_query_con_llm(query: str) -> dict:
    """
    Clasifica la query en una de 3 categorías y devuelve los parámetros correspondientes:
      - normal: query específica, no hace referencia al historial
      - historial_positivo: el usuario quiere algo típico o personalizado para él
      - historial_negativo: el usuario quiere algo distinto a su costumbre
    """
    prompt = f"""You are part of a movie recommendation system. Classify the following user query into exactly one of these three categories:

- "normal": the user describes what they want to watch specifically (genre, mood, theme, plot). No reference to their viewing history.
- "historial_positivo": the user wants something similar to what they usually watch, or their request is so vague that their history is the best guide.
- "historial_negativo": the user explicitly wants something DIFFERENT from their usual preferences.

User query: "{query}"

Examples:
"Quiero una película donde un hombre se enfrenta a una organización criminal" → "normal"
"No sé, algo que valga la pena" → "historial_positivo"
"Lo de siempre está bien" → "historial_positivo"
"Quiero algo distinto a lo que vengo viendo" → "historial_negativo"
"Sorpréndeme con algo que no elegiría yo" → "historial_negativo"

Respond ONLY with valid JSON, no extra text:
{{"categoria": "normal" | "historial_positivo" | "historial_negativo"}}"""

    response = ollama.chat(
        model='llama3.2',
        messages=[{'role': 'user', 'content': prompt}],
        format='json',
        options={'temperature': 0.1, 'seed': 42}
    )

    raw = response.message.content.strip()

    try:
        parsed = json_lib.loads(raw)
        categoria = parsed.get('categoria', 'normal').strip()
        if categoria not in CATEGORIA_PARAMS:
            print(f"[WARN] Categoría inválida '{categoria}', usando 'normal'")
            categoria = 'normal'
        params = CATEGORIA_PARAMS[categoria]
        return {
            'categoria': categoria,
            'weights': params['weights'],
            'direction': params['direction']
        }
    except Exception as e:
        print(f"[WARN] JSON parse error for query '{query[:40]}...': {e}")
        return {'categoria': 'normal', 'weights': [0.7, 0.3], 'direction': 'top-5'}

# %%
# Procesar todas las queries
resultados_llm = []
for query in usuarios['query']:
    res = procesar_query_con_llm(query)
    resultados_llm.append(res)
    print(f"Query:      {query}")
    print(f"Categoría:  {res['categoria']} | Weights: {res['weights']} | Dirección: {res['direction']}")
    print()

parametros_usuarios = [{'weights': r['weights'], 'direction': r['direction']} for r in resultados_llm]
# Out:
# Query:      Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Busco algo basado en hechos reales sobre corrupción o poder político
# Categoría:  historial_positivo | Weights: [0.1, 0.9] | Dirección: top-5
#
# Query:      Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
# Categoría:  historial_positivo | Weights: [0.1, 0.9] | Dirección: top-5
#
# Query:      Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Algo que sea difícil de clasificar, con una lógica narrativa propia, no convencional
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      No sé bien, algo que valga la pena ver un domingo a la noche, que enganche desde el principio
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      Quiero algo distinto a lo de siempre, pero tampoco tan raro, con buenas actuaciones supongo
# Categoría:  historial_negativo | Weights: [0.1, 0.9] | Dirección: bottom-5
#
# Query:      Algo que pueda ver con amigos o solo, que no sea muy larga ni muy corta
# Categoría:  normal | Weights: [0.7, 0.3] | Dirección: top-5
#
# Query:      No tengo ganas de pensar mucho, pero tampoco quiero algo vacío, algo intermedio
# Categoría:  historial_positivo | Weights: [0.1, 0.9] | Dirección: top-5

# %% [markdown]
# ### Análisis de la clasificación con el LLM
#
# La clasificación es **coherente con la redacción de las queries**:
#
# - La mayoría de las queries describen explícitamente qué se quiere ver (género, trama, atmósfera) y caen en **`normal`** (U1, U3, U5, U6, U7, U8, U9, U10, U11, U13).
# - **`historial_positivo`** aparece en queries vagas: U4 ("algo que haga pensar…") y U14 ("algo intermedio").
# - **`historial_negativo`** lo detecta solo en U12 ("quiero algo distinto a lo de siempre…"), que es exactamente el caso que justifica invertir la búsqueda (`bottom-5`).
#
# **Observaciones / límites:**
# - Algunas asignaciones son discutibles (p. ej. clasificar U2 y U4 como `historial_positivo` cuando las query sí son bastante específicas), lo que muestra que el LLM puede fallar en casos de frontera.
# - La calidad del enfoque depende de que la clasificación sea correcta: un error de categoría cambia drásticamente los pesos y la dirección de la búsqueda.

# %% [markdown]
# ### Calculo del embedding de usuario
#
# Para cada usuario combinamos su embedding de query y su embedding de historial con `np.average`, usando los **pesos** que devolvió la clasificación del LLM. El resultado es un vector de usuario que refleja, de forma controlada, cuánto debe pesar lo que pide ahora frente a lo que suele ver.

# %%
user_embeddings_dinamico = []

for i, params in enumerate(parametros_usuarios):
    w = params['weights']
    emb = np.average(
        [queries_embeddings[i], historial_embeddings[i]],
        axis=0,
        weights=w
    )
    user_embeddings_dinamico.append(emb)

user_embeddings_dinamico = np.array(user_embeddings_dinamico)

# %% [markdown]
# ### Recomendaciones

# %%
scores_dinamico = cosine_similarity(user_embeddings_dinamico, pelis_embeddings)

# Filtrar películas del historial seteando su score a -inf
hist_cols = ['pelicula_1', 'pelicula_2', 'pelicula_3', 'pelicula_4', 'pelicula_5']
scores_dinamico_filtrado = scores_dinamico.copy()

for i, row in usuarios.iterrows():
    for col in hist_cols:
        nombre = row[col]
        match = df_pelis[df_pelis['name'] == nombre].index
        if len(match):
            scores_dinamico_filtrado[i, match[0]] = -np.inf

# Top-5 por usuario según dirección
top5_indices_dinamico = []
for i, params in enumerate(parametros_usuarios):
    if params['direction'] == 'bottom-5':
        # Excluir los -inf del historial también para bottom-5
        scores_validos = scores_dinamico_filtrado[i].copy()
        scores_validos[scores_validos == -np.inf] = np.inf  # que no aparezcan en el bottom
        indices = scores_validos.argsort()[:5]
    else:
        indices = scores_dinamico_filtrado[i].argsort()[-5:][::-1]
    top5_indices_dinamico.append(indices)

top5_indices_dinamico = np.array(top5_indices_dinamico)  # shape: (14, 5)

# %% [markdown]
# ### Validación

# %%
resultados_eval_din = []

for user_idx, row in usuarios.head(9).iterrows():
    print(f"\n{'='*70}")
    print(f"{row['nombre']} ({row['tipo_perfil']})")
    print(f"Query: {row['query']}")
    params = parametros_usuarios[user_idx]
    print(f"Pesos: {params['weights']} | Dirección: {params['direction']}")
    generos_esperados = set(etiquetas_a_ojo_def[user_idx])
    print(f"Géneros Esperados: {', '.join(generos_esperados)}")
    print(f"{'='*70}")

    generos_recomendados = Counter()
    peliculas_buenas = 0
    peliculas_malas = []

    print("\nTop-5 Recomendaciones:")
    for rank, idx in enumerate(top5_indices_dinamico[user_idx], 1):
        pelicula = df_pelis.iloc[idx]
        score = scores_dinamico[user_idx, idx]

        generos_str = pelicula['genre'].strip('[]')
        generos_list = [g.strip() for g in generos_str.split(',')]
        generos_pelicula = set(generos_list)
        generos_recomendados.update(generos_list)

        es_buena = bool(generos_pelicula & generos_esperados)
        if es_buena:
            peliculas_buenas += 1
            marker = "✓"
        else:
            peliculas_malas.append(pelicula['name'])
            marker = "✗"

        print(f"  {rank}. [{marker}] {pelicula['name']} ({int(pelicula['year']) if not pd.isna(pelicula['year']) else 'N/A'}) — {score:.4f}")
        print(f"     Géneros: {', '.join(generos_list)}")

    print(f"\nConteo de Géneros en Recomendaciones:")
    for genero, freq in generos_recomendados.most_common():
        print(f"  {genero}: {freq}")

    generos_capturados = set(generos_recomendados.keys())
    recall = len(generos_capturados & generos_esperados) / len(generos_esperados)
    precision = peliculas_buenas / 5
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    print(f"\nMÉTRICAS:")
    print(f"  Recall (géneros):      {recall:.1%}  ({len(generos_capturados & generos_esperados)}/{len(generos_esperados)})")
    print(f"  Precision (películas): {precision:.1%}  ({peliculas_buenas}/5)")
    print(f"  F1-Score:              {f1:.1%}")

    if peliculas_malas:
        print(f"\nPelículas problemáticas (sin géneros esperados):")
        for pelicula in peliculas_malas:
            print(f"    - {pelicula}")

    resultados_eval_din.append({
        'Usuario': row['nombre'],
        'Recall': recall,
        'Precision': precision,
        'F1': f1,
        'Películas Malas': len(peliculas_malas),
        'Dirección': params['direction'],
        'Pesos': str(params['weights'])
    })

print(f"\n\n{'='*70}")
print("RESUMEN DE EVALUACIÓN — DINÁMICO")
print(f"{'='*70}")
df_eval_din = pd.DataFrame(resultados_eval_din)
df_eval_din.to_csv('evaluacion_transformer_promedio.csv', index=False)
print(df_eval_din.to_string(index=False))
print(f"\nPromedios:")
print(f"  Recall:    {df_eval_din['Recall'].mean():.1%}")
print(f"  Precision: {df_eval_din['Precision'].mean():.1%}")
print(f"  F1-Score:  {df_eval_din['F1'].mean():.1%}")
# Out:
# ======================================================================
# Valentina (definido)
# Query: Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: suspense, drama, terror
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] El ente (1983) — 0.6466
#      Géneros: drama, terror
#   2. [✓] Tránsito (2006) — 0.6377
#      Géneros: drama, misterio, suspense
#   3. [✓] Femme Fatale (2003) — 0.6356
#      Géneros: crimen, drama, misterio
#   4. [✗] Scary Movie 5 (2013) — 0.6113
#      Géneros: comedia
#   5. [✓] Alone in the Dark (2006) — 0.6111
#      Géneros: acción, terror, ciencia ficción
#
# Conteo de Géneros en Recomendaciones:
#   drama: 3
#   terror: 2
#   misterio: 2
#   suspense: 1
#   crimen: 1
#   comedia: 1
#   acción: 1
#   ciencia ficción: 1
#
# MÉTRICAS:
#   Recall (géneros):      100.0%  (3/3)
#   Precision (películas): 80.0%  (4/5)
#   F1-Score:              88.9%
#
# Películas problemáticas (sin géneros esperados):
#     - Scary Movie 5
#
# ======================================================================
# Rodrigo (definido)
# Query: Busco algo basado en hechos reales sobre corrupción o poder político
# Pesos: [0.1, 0.9] | Dirección: top-5
# Géneros Esperados: biografía, historia, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] El sabor de la muerte (1995) — 0.7069
#      Géneros: crimen, drama, suspense
#   2. [✓] Infierno en Los Ángeles (1993) — 0.6988
#      Géneros: crimen, drama, suspense
#   3. [✓] Pasos de baile (2002) — 0.6915
#      Géneros: crimen, drama, suspense
#   4. [✓] Fuga mortal (1993) — 0.6859
#      Géneros: acción, aventura, crimen
#   5. [✗] La zona muerta (1983) — 0.6797
#      Géneros: drama, terror, ciencia ficción
#
# Conteo de Géneros en Recomendaciones:
#   crimen: 4
#   drama: 4
#   suspense: 3
#   acción: 1
#   aventura: 1
#   terror: 1
#   ciencia ficción: 1
#
# MÉTRICAS:
#   Recall (géneros):      33.3%  (1/3)
#   Precision (películas): 80.0%  (4/5)
#   F1-Score:              47.1%
#
# Películas problemáticas (sin géneros esperados):
#     - La zona muerta
#
# ======================================================================
# Camila (definido)
# Query: Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: romance, drama, comedia
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Escuela de novatos (2004) — 0.7542
#      Géneros: comedia, crimen, misterio
#   2. [✓] La pareja basura (1991) — 0.7352
#      Géneros: comedia
#   3. [✓] Misterioso asesinato en Manhattan (1994) — 0.7272
#      Géneros: comedia, misterio
#   4. [✓] La comedia sexual de una noche de verano (1982) — 0.7067
#      Géneros: comedia
#   5. [✓] Ensalada de gemelas (1988) — 0.6898
#      Géneros: comedia
#
# Conteo de Géneros en Recomendaciones:
#   comedia: 5
#   misterio: 2
#   crimen: 1
#
# MÉTRICAS:
#   Recall (géneros):      33.3%  (1/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:              50.0%
#
# ======================================================================
# Tomás (definido)
# Query: Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
# Pesos: [0.1, 0.9] | Dirección: top-5
# Géneros Esperados: ciencia ficción, suspense, acción
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✗] El jardinero fiel (2005) — 0.7384
#      Géneros: drama, misterio, romance
#   2. [✓] Memorias de un hombre invisible (1993) — 0.7346
#      Géneros: comedia, romance, ciencia ficción
#   3. [✓] Cypher (2004) — 0.7245
#      Géneros: misterio, ciencia ficción, suspense
#   4. [✓] La trama (1998) — 0.7111
#      Géneros: drama, misterio, suspense
#   5. [✓] La zona muerta (1983) — 0.7104
#      Géneros: drama, terror, ciencia ficción
#
# Conteo de Géneros en Recomendaciones:
#   drama: 3
#   misterio: 3
#   ciencia ficción: 3
#   romance: 2
#   suspense: 2
#   comedia: 1
#   terror: 1
#
# MÉTRICAS:
#   Recall (géneros):      66.7%  (2/3)
#   Precision (películas): 80.0%  (4/5)
#   F1-Score:              72.7%
#
# Películas problemáticas (sin géneros esperados):
#     - El jardinero fiel
#
# ======================================================================
# Lucía (definido)
# Query: Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: aventura, animación, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✗] Daredevil (2003) — 0.6529
#      Géneros: acción, crimen
#   2. [✗] Virtuosity (1995) — 0.6474
#      Géneros: acción, crimen, ciencia ficción
#   3. [✓] Número 9 (2010) — 0.6276
#      Géneros: animación, acción, aventura
#   4. [✓] Cuentos de Terramar (2006) — 0.6233
#      Géneros: animación, aventura, fantasía
#   5. [✓] Code Geass: Lelouch of the Rebellion (2006) — 0.6178
#      Géneros: animación, acción, drama
#
# Conteo de Géneros en Recomendaciones:
#   acción: 4
#   animación: 3
#   crimen: 2
#   aventura: 2
#   ciencia ficción: 1
#   fantasía: 1
#   drama: 1
#
# MÉTRICAS:
#   Recall (géneros):      100.0%  (3/3)
#   Precision (películas): 60.0%  (3/5)
#   F1-Score:              75.0%
#
# Películas problemáticas (sin géneros esperados):
#     - Daredevil
#     - Virtuosity
#
# ======================================================================
# Martín (definido)
# Query: Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: comedia, acción, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Plan oculto (2006) — 0.6771
#      Géneros: crimen, drama, misterio
#   2. [✓] Supercañeras: El internado puede ser una fiesta (2009) — 0.6365
#      Géneros: comedia, familiar
#   3. [✓] Heat (1996) — 0.6323
#      Géneros: acción, crimen, drama
#   4. [✓] Sin motivo aparente (2003) — 0.6320
#      Géneros: crimen, drama, suspense
#   5. [✓] Albino Alligator (1997) — 0.6316
#      Géneros: crimen, drama, suspense
#
# Conteo de Géneros en Recomendaciones:
#   crimen: 4
#   drama: 4
#   suspense: 2
#   misterio: 1
#   comedia: 1
#   familiar: 1
#   acción: 1
#
# MÉTRICAS:
#   Recall (géneros):      100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:              100.0%
#
# ======================================================================
# Sofía (definido)
# Query: Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: comedia, música, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✗] Aquarius (1987) — 0.6330
#      Géneros: terror, suspense
#   2. [✓] Once (2007) — 0.6207
#      Géneros: drama, música, romance
#   3. [✓] Ragtime (1982) — 0.6166
#      Géneros: drama
#   4. [✓] La diva (1981) — 0.6160
#      Géneros: comedia, crimen, música
#   5. [✓] Slacker (1991) — 0.6159
#      Géneros: comedia, drama
#
# Conteo de Géneros en Recomendaciones:
#   drama: 3
#   música: 2
#   comedia: 2
#   terror: 1
#   suspense: 1
#   romance: 1
#   crimen: 1
#
# MÉTRICAS:
#   Recall (géneros):      100.0%  (3/3)
#   Precision (películas): 80.0%  (4/5)
#   F1-Score:              88.9%
#
# Películas problemáticas (sin géneros esperados):
#     - Aquarius
#
# ======================================================================
# Diego (definido)
# Query: Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: aventura, acción, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] El único (2002) — 0.7011
#      Géneros: acción, ciencia ficción, suspense
#   2. [✓] The Punisher (El castigador) (2004) — 0.6969
#      Géneros: acción, crimen, drama
#   3. [✓] El coche fantástico (N/A) — 0.6889
#      Géneros: acción, crimen, drama
#   4. [✓] Snake Eyes (Ojos de serpiente) (1998) — 0.6880
#      Géneros: crimen, misterio, suspense
#   5. [✓] El poder del talismán (2003) — 0.6794
#      Géneros: acción, comedia, fantasía
#
# Conteo de Géneros en Recomendaciones:
#   acción: 4
#   crimen: 3
#   suspense: 2
#   drama: 2
#   ciencia ficción: 1
#   misterio: 1
#   comedia: 1
#   fantasía: 1
#
# MÉTRICAS:
#   Recall (géneros):      66.7%  (2/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:              80.0%
#
# ======================================================================
# Elena (definido)
# Query: Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
# Pesos: [0.7, 0.3] | Dirección: top-5
# Géneros Esperados: romance, comedia, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] El orfanato (2007) — 0.6051
#      Géneros: aventura, drama, terror
#   2. [✓] A la deriva (2006) — 0.5909
#      Géneros: aventura, drama, terror
#   3. [✓] Red Rock West (1995) — 0.5878
#      Géneros: crimen, drama, suspense
#   4. [✗] La tostadora valiente (1994) — 0.5740
#      Géneros: animación, aventura, familiar
#   5. [✗] Reeker (2006) — 0.5737
#      Géneros: terror, misterio, suspense
#
# Conteo de Géneros en Recomendaciones:
#   aventura: 3
#   drama: 3
#   terror: 3
#   suspense: 2
#   crimen: 1
#   animación: 1
#   familiar: 1
#   misterio: 1
#
# MÉTRICAS:
#   Recall (géneros):      33.3%  (1/3)
#   Precision (películas): 60.0%  (3/5)
#   F1-Score:              42.9%
#
# Películas problemáticas (sin géneros esperados):
#     - La tostadora valiente
#     - Reeker
#
#
# ======================================================================
# RESUMEN DE EVALUACIÓN — DINÁMICO
# ======================================================================
#   Usuario   Recall  Precision       F1  Películas Malas Dirección      Pesos
# Valentina 1.000000        0.8 0.888889                1     top-5 [0.7, 0.3]
#   Rodrigo 0.333333        0.8 0.470588                1     top-5 [0.1, 0.9]
#    Camila 0.333333        1.0 0.500000                0     top-5 [0.7, 0.3]
#     Tomás 0.666667        0.8 0.727273                1     top-5 [0.1, 0.9]
#     Lucía 1.000000        0.6 0.750000                2     top-5 [0.7, 0.3]
#    Martín 1.000000        1.0 1.000000                0     top-5 [0.7, 0.3]
#     Sofía 1.000000        0.8 0.888889                1     top-5 [0.7, 0.3]
#     Diego 0.666667        1.0 0.800000                0     top-5 [0.7, 0.3]
#     Elena 0.333333        0.6 0.428571                2     top-5 [0.7, 0.3]
#
# Promedios:
#   Recall:    70.4%
#   Precision: 82.2%
#   F1-Score:  71.7%

# %% [markdown]
# + Valentina: query común con F1 88.9%, todos los generos esperados fueron capturados. La única película problemática es Scary Movie, que por su título es un error aceptable. Las recomendaciones que más cumplen con lo solicitado:
#     + El ente (1983): cumple casi a la perfección con la query. Trata sobre una mujer atacada por un demonio invisible.
#     + Femme Fatale (2003): mujer protagonista. Puede que el modelo confunda "su pasado como estafadora regresa para perseguirla" como la amenaza invisible.
#
# + Rodrigo: Se categorizó mal su query, dandole excesivo peso a su historial. Las recomendaciónes no muestran los géneros biografía ni historia. Aún así no están tan mal, gracias a que su query es bastante consistente con su historial.
#
# + Camila: query común con F1 de 50%. Todas las películas son comedias pero no se capturan todos los géneros esperados, esto puede ser por una mala clasificación de las películas. Las recomendaciones que más cumplen con lo solicitado:
#     + Escuela de novatos (2004): comedia que empieza con dos personajes conociendoce en una situación ridícula.
#     + Ensalada de gemelas (1988): comedia donde cuatro personajes se conocen de manera extraña.

# %% [markdown]
# Todas las métricas cayeron en relación con el enfoque anterior, pero parecen funcionar de manera similar. Hay que recordar que las métricas están basadas en suposiciones a ojo y que los generos de las películas pueden estar mal asignados (hemos visto varios casos).

# %% [markdown]
# ## Enfoque 3 — Topic Modeling con BERTopic
#
# Tercera estrategia de representación, conceptualmente distinta a las anteriores. En vez de comparar embeddings densos directamente, **descubrimos tópicos latentes** en el corpus con BERTopic (reducción de dimensionalidad + clustering sobre los embeddings) y representamos cada película por su **distribución de probabilidad sobre esos tópicos**.
#
# A cada usuario lo representamos del mismo modo (su texto query+historial proyectado a la distribución de tópicos) y recomendamos por similitud entre distribuciones.

# %% [markdown]
# ### Instanciamos BERTopic
#
# Instanciamos con configuración mínima, vamos a usar BERTopic con sus componentes por defecto.
#
# Le pasamos los embeddings precomputados y el mismo _transformer_ que venimos usando.

# %%
topic_model = BERTopic(
    embedding_model=model,
    calculate_probabilities=True,
    verbose=True
    )

topics, probs = topic_model.fit_transform(df_pelis["texto"].tolist(), pelis_embeddings)
# Out:
# 2026-06-15 19:30:01,649 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-06-15 19:30:47,672 - BERTopic - Dimensionality - Completed ✓
# 2026-06-15 19:30:47,674 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-06-15 19:30:49,909 - BERTopic - Cluster - Completed ✓
# 2026-06-15 19:30:49,925 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-06-15 19:30:50,397 - BERTopic - Representation - Completed ✓

# %% [markdown]
# Vemos la cantidad de tópicos encontrados y su count

# %%
# Número de tópicos encontrados (excluye -1 = outliers)
n_topics = len(topic_model.get_topics()) - 1
print(f"Tópicos encontrados: {n_topics}")
print(f"Outliers (tópico -1): {topics.count(-1)}")
# Out:
# Tópicos encontrados: 70
# Outliers (tópico -1): 2725

# %%
topic_model.get_topic_info().head(10)
# Out:
#    Topic  Count                                    Name  \
# 0     -1   2725                          -1_de_un_en_la
# 1      0    120     0_alienígena_ficción_ciencia_tierra
# 2      1    117          1_romance_mujer_sex_matrimonio
# 3      2    102          2_tiempo_ciencia_ficción_virus
# 4      3     92        3_fantasía_aventura_el_animación
# 5      4     88         4_guerra_vietnam_bélico_soldado
# 6      5     79                5_familia_madre_padre_su
# 7      6     75        6_policía_police_crimen_policías
# 8      7     61   7_instituto_comedia_universidad_grupo
# 9      8     56  8_detective_policía_asesinato_misterio
#
#                                       Representation  \
# 0  [de, un, en, la, una, el, su, que, drama, come...
# 1  [alienígena, ficción, ciencia, tierra, alieníg...
# 2  [romance, mujer, sex, matrimonio, se, boda, un...
# 3  [tiempo, ciencia, ficción, virus, terror, máqu...
# 4  [fantasía, aventura, el, animación, dragón, re...
# 5  [guerra, vietnam, bélico, soldado, soldados, w...
# 6  [familia, madre, padre, su, relación, hijo, hi...
# 7  [policía, police, crimen, policías, cop, de, a...
# 8  [instituto, comedia, universidad, grupo, estud...
# 9  [detective, policía, asesinato, misterio, crim...
#
#                                  Representative_Docs
# 0  [El último beso. The Last Kiss es una comedia ...
# 1  [Farscape. Perdido en una parte distante del u...
# 2  [Novio por una noche. Para evitar que la mujer...
# 3  [La máquina del tiempo. Un inventor del siglo ...
# 4  [Conan, el bárbaro. Un guerrero bárbaro quiere...
# 5  [El gran rescate. A finales de la Segunda Guer...
# 6  [En lo profundo del océano. Una familia reacci...
# 7  [The Corruptor. Con la ayuda de un policía neo...
# 8  [Chicas malas. Cady Heron intenta adaptarse a ...
# 9  [Insomnio. Dos detectives de homicidios de Los...

# %% [markdown]
# Documentos más representativos del tópico 8_detective_policía_asesinato_misterio

# %%
print("Documentos representativos del tópico 8:\n")
for doc in topic_model.get_representative_docs(8):
    print(doc[:100])
    print("---")
# Out:
# Documentos representativos del tópico 8:
#
# Insomnio. Dos detectives de homicidios de Los Ángeles son enviados a un pueblo del norte donde el so
# ---
# Homicidio. Un detective de homicidios judío investiga lo que parece un simple caso de asesinato pero
# ---
# Caso abierto. La única mujer detective de la brigada de homicidios de Filadelfia encuentra su vocaci
# ---

# %% [markdown]
# ### Representación del usuario en el espacio de tópicos
#
# Para cada usuario concatenamos su **query + el texto de su historial** y usamos `topic_model.transform` para obtener su **distribución sobre los tópicos**. Así el usuario queda representado en el mismo espacio que las películas y podemos compararlos por similitud coseno entre distribuciones.

# %%
def build_user_text(usuario_row, pelis_df):
    """Construye el texto concatenado para un usuario"""
    user_text = usuario_row['query']
    
    for col in ['pelicula_1','pelicula_2','pelicula_3','pelicula_4','pelicula_5']:
        nombre = usuario_row[col]
        peli = pelis_df[pelis_df['name'] == nombre]
        if not peli.empty:
            user_text += " " + peli["texto"].values[0]
    
    return user_text

# %%
usuarios['texto'] = usuarios.apply(lambda row: build_user_text(row, df_pelis), axis=1)

# %%
_, users_probs = topic_model.transform(usuarios['texto'].tolist())

print(f"users_probs shape: {users_probs.shape}")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-15 19:32:37,766 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2026-06-15 19:33:05,092 - BERTopic - Dimensionality - Completed ✓
# 2026-06-15 19:33:05,093 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2026-06-15 19:33:05,102 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2026-06-15 19:33:05,113 - BERTopic - Probabilities - Completed ✓
# 2026-06-15 19:33:05,114 - BERTopic - Cluster - Completed ✓
# users_probs shape: (14, 70)

# %% [markdown]
# ### Recomendaciones

# %%
# Calcular similitud coseno
scores_tm = cosine_similarity(users_probs, probs)

# Crear máscara de películas ya vistas
scores_filtered = scores_tm.copy()

for i, row in usuarios.iterrows():
    historial_names = [row['pelicula_1'], row['pelicula_2'], row['pelicula_3'], 
                       row['pelicula_4'], row['pelicula_5']]
    
    # Encontrar índices de películas en el historial
    historial_indices = df_pelis[df_pelis['name'].isin(historial_names)].index
    
    # Asignar -inf para que no salgan en top-5
    scores_filtered[i, historial_indices] = -np.inf

# Top-5 por usuario
top5_indices_tm = scores_tm.argsort(axis=1)[:, -5:][:, ::-1]

# Ver resultados
for i, row in usuarios.iterrows():
    print(f"\n{row['nombre']} ({row['tipo_perfil']})")
    print(f"Query: {row['query']}")
    for idx in top5_indices_tm[i]:
        pelicula = df_pelis.iloc[idx]
        print(f"  {pelicula['name']} ({int(pelicula['year'])}) — {scores_tm[i, idx]:.4f}")
# Out:
# Valentina (definido)
# Query: Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
#   El americano impasible (2003) — 0.7679
#   Edición anterior (1996) — 0.7623
#   Miedo y asco en Las Vegas (1999) — 0.7608
#   Los diarios del ron (2012) — 0.7583
#   El año que vivimos peligrosamente (1983) — 0.7515
#
# Rodrigo (definido)
# Query: Busco algo basado en hechos reales sobre corrupción o poder político
#   Los 4400 (2005) — 1.0000
#   Espera al último baile (2001) — 1.0000
#   Hasta el final (1997) — 1.0000
#   El guardaespaldas (1992) — 1.0000
#   Monster's Ball (2002) — 1.0000
#
# Camila (definido)
# Query: Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
#   Dos chalados y muchas curvas (2005) — 0.8777
#   Mi padre, ¡qué ligue! (1994) — 0.8761
#   Solo tú (1994) — 0.8732
#   La fuerza del amor (2000) — 0.8699
#   Elizabethtown (2005) — 0.8699
#
# Tomás (definido)
# Query: Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
#   Speed 2 (1997) — 1.0000
#   Las alucinantes aventuras de Bill y Ted (1989) — 1.0000
#   28 semanas después (2007) — 1.0000
#   Juegos de guerra (1983) — 1.0000
#   Piratas de Silicon Valley (1999) — 1.0000
#
# Lucía (definido)
# Query: Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
#   The Drew Carey Show (1995) — 1.0000
#   Chappelle's Show (2003) — 1.0000
#   Punky Brewster (1994) — 1.0000
#   Joey (2004) — 1.0000
#   Las noticias de Jon Stewart (1996) — 1.0000
#
# Martín (definido)
# Query: Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
#   John Q (2002) — 0.9925
#   Monjas a la carrera (1990) — 0.9925
#   ¡Que te calles! (2004) — 0.9925
#   Luna negra (1987) — 0.9925
#   Nacer para morir (2003) — 0.9925
#
# Sofía (definido)
# Query: Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
#   I'm Not There (2010) — 0.8984
#   Honey (2004) — 0.8982
#   El pianista (2002) — 0.8971
#   Velvet Goldmine (1999) — 0.8970
#   El violín rojo (1999) — 0.8962
#
# Diego (definido)
# Query: Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
#   Distrito 13 (2004) — 0.8971
#   Dark Blue (2004) — 0.8924
#   Teniente corrupto (1994) — 0.8913
#   Acero azul (1990) — 0.8900
#   Medidas desesperadas (1998) — 0.8898
#
# Elena (definido)
# Query: Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
#   Cinco hermanos (2007) — 0.8265
#   Una familia tronada (1986) — 0.8264
#   Los magos de Waverly Place (2007) — 0.8256
#   Cómo conocí a vuestra madre (2005) — 0.8244
#   Evelyn (2003) — 0.8240
#
# Facundo (definido)
# Query: Algo que sea difícil de clasificar, con una lógica narrativa propia, no convencional
#   Ausente (2008) — 0.8077
#   Monk (2004) — 0.8074
#   Sin perdón (1992) — 0.8070
#   Algunos hombres buenos (1992) — 0.8052
#   Jungla de cristal (1988) — 0.8040
#
# Julián (ambiguo)
# Query: No sé bien, algo que valga la pena ver un domingo a la noche, que enganche desde el principio
#   Dungeons & Dragons (Dragones y mazmorras) (2001) — 0.9755
#   Conan, el destructor (1984) — 0.9753
#   Excalibur (1981) — 0.9752
#   El dragón del lago de fuego (1982) — 0.9743
#   El señor de las bestias (1982) — 0.9738
#
# Mariana (ambiguo)
# Query: Quiero algo distinto a lo de siempre, pero tampoco tan raro, con buenas actuaciones supongo
#   El gran debate (2007) — 0.8310
#   Psycho Beach Party (2001) — 0.8306
#   La primera experiencia (1991) — 0.8254
#   Bienvenido a la casa de muñecas (1998) — 0.8231
#   Academia Rushmore (1999) — 0.8225
#
# Nicolás (ambiguo)
# Query: Algo que pueda ver con amigos o solo, que no sea muy larga ni muy corta
#   Sangre por sangre (1993) — 0.9779
#   El sueño de Arizona (1993) — 0.9770
#   El gurú del buen rollo (2008) — 0.9764
#   Bhagam Bhag (2006) — 0.9749
#   En el valle (2005) — 0.9735
#
# Paula (ambiguo)
# Query: No tengo ganas de pensar mucho, pero tampoco quiero algo vacío, algo intermedio
#   En el estanque dorado (1982) — 0.8944
#   El mundo según Garp (1983) — 0.8935
#   Californication (2008) — 0.8933
#   Superstar (2000) — 0.8918
#   Más allá del tiempo (2010) — 0.8899

# %% [markdown]
# ### Validación

# %%
resultados_eval = []

for user_idx, row in usuarios.head(9).iterrows():
    print(f"\n{'='*70}")
    print(f"{row['nombre']} ({row['tipo_perfil']})")
    print(f"Query: {row['query']}")
    generos_esperados = set(etiquetas_a_ojo_def[user_idx])
    print(f"Géneros Esperados: {', '.join(generos_esperados)}")
    print(f"{'='*70}")
    
    generos_recomendados = Counter()
    peliculas_buenas = 0  # con al menos 1 género esperado
    peliculas_malas = []  # sin ningún género esperado
    
    print("\nTop-5 Recomendaciones:")
    for rank, idx in enumerate(top5_indices_tm[user_idx], 1):
        pelicula = df_pelis.iloc[idx]
        score = scores_tm[user_idx, idx]
        
        # Extraer géneros
        generos_str = pelicula['genre'].strip('[]')
        generos_list = [g.strip() for g in generos_str.split(',')]
        generos_pelicula = set(generos_list)
        generos_recomendados.update(generos_list)
        
        # ¿Tiene algún género esperado?
        es_buena = bool(generos_pelicula & generos_esperados)
        if es_buena:
            peliculas_buenas += 1
            marker = "✓"
        else:
            peliculas_malas.append(pelicula['name'])
            marker = "✗"
        
        print(f"  {rank}. [{marker}] {pelicula['name']} ({int(pelicula['year']) if not pd.isna(pelicula['year']) else 'N/A'}) — {score:.4f}")
        print(f"     Géneros: {', '.join(generos_list)}")
    
    # Conteo de géneros
    print(f"\nConteo de Géneros en Recomendaciones:")
    for genero, freq in generos_recomendados.most_common():
        print(f"  {genero}: {freq}")
    
    # Métricas
    generos_capturados = set(generos_recomendados.keys())
    recall = len(generos_capturados & generos_esperados) / len(generos_esperados)
    precision = peliculas_buenas / 5  # top-5
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    print(f"\nMÉTRICAS:")
    print(f"  Recall (géneros):     {recall:.1%}  ({len(generos_capturados & generos_esperados)}/{len(generos_esperados)})")
    print(f"  Precision (películas): {precision:.1%}  ({peliculas_buenas}/5)")
    print(f"  F1-Score:            {f1:.1%}")
    
    if peliculas_malas:
        print(f"\nPelículas problemáticas (sin géneros esperados):")
        for pelicula in peliculas_malas:
            print(f"    - {pelicula}")
    
    resultados_eval.append({
        'Usuario': row['nombre'],
        'Recall': recall,
        'Precision': precision,
        'F1': f1,
        'Películas Malas': len(peliculas_malas)
    })

# Resumen
print(f"\n\n{'='*70}")
print("RESUMEN DE EVALUACIÓN")
print(f"{'='*70}")
df_eval = pd.DataFrame(resultados_eval)
df_eval.to_csv("evaluacion_topic_modeling.csv", index=False)
print(df_eval.to_string(index=False))
print(f"\nPromedios:")
print(f"  Recall:    {df_eval['Recall'].mean():.1%}")
print(f"  Precision: {df_eval['Precision'].mean():.1%}")
print(f"  F1-Score:  {df_eval['F1'].mean():.1%}")
# Out:
# ======================================================================
# Valentina (definido)
# Query: Quiero una película donde una mujer enfrenta una amenaza invisible que viene de alguien cercano
# Géneros Esperados: suspense, drama, terror
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] El americano impasible (2003) — 0.7679
#      Géneros: drama, romance, suspense
#   2. [✓] Edición anterior (1996) — 0.7623
#      Géneros: aventura, comedia, drama
#   3. [✓] Miedo y asco en Las Vegas (1999) — 0.7608
#      Géneros: aventura, comedia, drama
#   4. [✓] Los diarios del ron (2012) — 0.7583
#      Géneros: comedia, drama
#   5. [✓] El año que vivimos peligrosamente (1983) — 0.7515
#      Géneros: drama, romance, bélico
#
# Conteo de Géneros en Recomendaciones:
#   drama: 5
#   comedia: 3
#   romance: 2
#   aventura: 2
#   suspense: 1
#   bélico: 1
#
# MÉTRICAS:
#   Recall (géneros):     66.7%  (2/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            80.0%
#
# ======================================================================
# Rodrigo (definido)
# Query: Busco algo basado en hechos reales sobre corrupción o poder político
# Géneros Esperados: biografía, historia, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✗] Los 4400 (2005) — 1.0000
#      Géneros: drama, misterio, ciencia ficción
#   2. [✗] Espera al último baile (2001) — 1.0000
#      Géneros: drama, música, romance
#   3. [✓] Hasta el final (1997) — 1.0000
#      Géneros: acción, crimen, drama
#   4. [✗] El guardaespaldas (1992) — 1.0000
#      Géneros: acción, drama, música
#   5. [✗] Monster's Ball (2002) — 1.0000
#      Géneros: drama, romance
#
# Conteo de Géneros en Recomendaciones:
#   drama: 5
#   música: 2
#   romance: 2
#   acción: 2
#   misterio: 1
#   ciencia ficción: 1
#   crimen: 1
#
# MÉTRICAS:
#   Recall (géneros):     33.3%  (1/3)
#   Precision (películas): 20.0%  (1/5)
#   F1-Score:            25.0%
#
# Películas problemáticas (sin géneros esperados):
#     - Los 4400
#     - Espera al último baile
#     - El guardaespaldas
#     - Monster's Ball
#
# ======================================================================
# Camila (definido)
# Query: Una comedia donde la relación entre dos personas empieza de forma ridícula o accidental
# Géneros Esperados: romance, drama, comedia
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Dos chalados y muchas curvas (2005) — 0.8777
#      Géneros: comedia
#   2. [✓] Mi padre, ¡qué ligue! (1994) — 0.8761
#      Géneros: comedia, romance
#   3. [✓] Solo tú (1994) — 0.8732
#      Géneros: comedia, romance
#   4. [✓] La fuerza del amor (2000) — 0.8699
#      Géneros: comedia, drama, romance
#   5. [✓] Elizabethtown (2005) — 0.8699
#      Géneros: comedia, drama, romance
#
# Conteo de Géneros en Recomendaciones:
#   comedia: 5
#   romance: 4
#   drama: 2
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Tomás (definido)
# Query: Algo que haga pensar sobre qué es real y qué es una construcción, con acción pero también ideas
# Géneros Esperados: ciencia ficción, suspense, acción
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Speed 2 (1997) — 1.0000
#      Géneros: acción, aventura, crimen
#   2. [✗] Las alucinantes aventuras de Bill y Ted (1989) — 1.0000
#      Géneros: aventura, comedia, música
#   3. [✓] 28 semanas después (2007) — 1.0000
#      Géneros: acción, aventura, terror
#   4. [✓] Juegos de guerra (1983) — 1.0000
#      Géneros: acción, drama, ciencia ficción
#   5. [✗] Piratas de Silicon Valley (1999) — 1.0000
#      Géneros: biografía, drama, historia
#
# Conteo de Géneros en Recomendaciones:
#   acción: 3
#   aventura: 3
#   drama: 2
#   crimen: 1
#   comedia: 1
#   música: 1
#   terror: 1
#   ciencia ficción: 1
#   biografía: 1
#   historia: 1
#
# MÉTRICAS:
#   Recall (géneros):     66.7%  (2/3)
#   Precision (películas): 60.0%  (3/5)
#   F1-Score:            63.2%
#
# Películas problemáticas (sin géneros esperados):
#     - Las alucinantes aventuras de Bill y Ted
#     - Piratas de Silicon Valley
#
# ======================================================================
# Lucía (definido)
# Query: Animación donde el protagonista lucha por su libertad o identidad en un mundo que lo oprime
# Géneros Esperados: aventura, animación, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✗] The Drew Carey Show (1995) — 1.0000
#      Géneros: comedia
#   2. [✗] Chappelle's Show (2003) — 1.0000
#      Géneros: comedia, música
#   3. [✗] Punky Brewster (1994) — 1.0000
#      Géneros: comedia, familiar
#   4. [✗] Joey (2004) — 1.0000
#      Géneros: comedia, romance
#   5. [✗] Las noticias de Jon Stewart (1996) — 1.0000
#      Géneros: comedia, noticias, tertulia
#
# Conteo de Géneros en Recomendaciones:
#   comedia: 5
#   música: 1
#   familiar: 1
#   romance: 1
#   noticias: 1
#   tertulia: 1
#
# MÉTRICAS:
#   Recall (géneros):     0.0%  (0/3)
#   Precision (películas): 0.0%  (0/5)
#   F1-Score:            0.0%
#
# Películas problemáticas (sin géneros esperados):
#     - The Drew Carey Show
#     - Chappelle's Show
#     - Punky Brewster
#     - Joey
#     - Las noticias de Jon Stewart
#
# ======================================================================
# Martín (definido)
# Query: Un grupo de personas planea un robo o estafa y las cosas se complican de forma inesperada
# Géneros Esperados: comedia, acción, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] John Q (2002) — 0.9925
#      Géneros: crimen, drama, suspense
#   2. [✓] Monjas a la carrera (1990) — 0.9925
#      Géneros: comedia, crimen
#   3. [✓] ¡Que te calles! (2004) — 0.9925
#      Géneros: comedia, crimen
#   4. [✓] Luna negra (1987) — 0.9925
#      Géneros: acción, crimen, suspense
#   5. [✓] Nacer para morir (2003) — 0.9925
#      Géneros: acción, crimen, drama
#
# Conteo de Géneros en Recomendaciones:
#   crimen: 5
#   drama: 2
#   suspense: 2
#   comedia: 2
#   acción: 2
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
# ======================================================================
# Sofía (definido)
# Query: Una película sobre músicos o artistas que viven al margen, con mucha atmósfera y estilo visual
# Géneros Esperados: comedia, música, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] I'm Not There (2010) — 0.8984
#      Géneros: biografía, drama, música
#   2. [✓] Honey (2004) — 0.8982
#      Géneros: drama, música, romance
#   3. [✓] El pianista (2002) — 0.8971
#      Géneros: biografía, drama, música
#   4. [✓] Velvet Goldmine (1999) — 0.8970
#      Géneros: drama, música
#   5. [✓] El violín rojo (1999) — 0.8962
#      Géneros: drama, música, misterio
#
# Conteo de Géneros en Recomendaciones:
#   drama: 5
#   música: 5
#   biografía: 2
#   romance: 1
#   misterio: 1
#
# MÉTRICAS:
#   Recall (géneros):     66.7%  (2/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            80.0%
#
# ======================================================================
# Diego (definido)
# Query: Acción directa con un héroe que trabaja solo o casi solo contra una organización criminal o corrupta
# Géneros Esperados: aventura, acción, crimen
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Distrito 13 (2004) — 0.8971
#      Géneros: acción, crimen, ciencia ficción
#   2. [✓] Dark Blue (2004) — 0.8924
#      Géneros: crimen, drama, suspense
#   3. [✓] Teniente corrupto (1994) — 0.8913
#      Géneros: crimen, drama, suspense
#   4. [✓] Acero azul (1990) — 0.8900
#      Géneros: acción, crimen, drama
#   5. [✓] Medidas desesperadas (1998) — 0.8898
#      Géneros: acción, crimen, drama
#
# Conteo de Géneros en Recomendaciones:
#   crimen: 5
#   drama: 4
#   acción: 3
#   suspense: 2
#   ciencia ficción: 1
#
# MÉTRICAS:
#   Recall (géneros):     66.7%  (2/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            80.0%
#
# ======================================================================
# Elena (definido)
# Query: Algo tranquilo sobre personas que intentan reconectar o entenderse después de una distancia larga
# Géneros Esperados: romance, comedia, drama
# ======================================================================
#
# Top-5 Recomendaciones:
#   1. [✓] Cinco hermanos (2007) — 0.8265
#      Géneros: drama
#   2. [✓] Una familia tronada (1986) — 0.8264
#      Géneros: acción, comedia
#   3. [✓] Los magos de Waverly Place (2007) — 0.8256
#      Géneros: aventura, comedia, drama
#   4. [✓] Cómo conocí a vuestra madre (2005) — 0.8244
#      Géneros: comedia, romance
#   5. [✓] Evelyn (2003) — 0.8240
#      Géneros: drama
#
# Conteo de Géneros en Recomendaciones:
#   drama: 3
#   comedia: 3
#   acción: 1
#   aventura: 1
#   romance: 1
#
# MÉTRICAS:
#   Recall (géneros):     100.0%  (3/3)
#   Precision (películas): 100.0%  (5/5)
#   F1-Score:            100.0%
#
#
# ======================================================================
# RESUMEN DE EVALUACIÓN
# ======================================================================
#   Usuario   Recall  Precision       F1  Películas Malas
# Valentina 0.666667        1.0 0.800000                0
#   Rodrigo 0.333333        0.2 0.250000                4
#    Camila 1.000000        1.0 1.000000                0
#     Tomás 0.666667        0.6 0.631579                2
#     Lucía 0.000000        0.0 0.000000                5
#    Martín 1.000000        1.0 1.000000                0
#     Sofía 0.666667        1.0 0.800000                0
#     Diego 0.666667        1.0 0.800000                0
#     Elena 1.000000        1.0 1.000000                0
#
# Promedios:
#   Recall:    66.7%
#   Precision: 75.6%
#   F1-Score:  69.8%

# %% [markdown]
# Este enfoque parece no ser el ideal para el problema. Algunos usuarios (Camila, Martín) alcanzaron F1=100%, otros (Lucía) F1=0%, sugiriendo que el método no generaliza bien.

# %% [markdown]
# ## Resultados
#
# **ST y ST+LLM** generaron recomendaciones significativamente mejores que **BERTopic**. Aunque los resultados en ambos casos fueron subóptimos, los embeddings densos mantuvieron coherencia semántica.
#
# ### Limitaciones del problema
#
# - **Dataset pequeño con historial escaso**: 14 usuarios con 5 películas cada uno es insuficiente para una validación robusta.
# - **Etiquetado subjetivo**: Géneros esperados asignados manualmente, sin consenso.
# - **Géneros incorrectos o faltantes**: Los géneros de las películas pueden estar mal asignados o géneros descriptivos pueden estar ausentes.
# - **Métricas permisivas**: Una película con un género esperado se considera "correcta", aunque sea una coincidencia parcial.
#
# ### Mejoras sugeridas
#
# 1. Expandir el dataset de peliculas de imdb con el resumen generado a partir de reseñas presente en la web.
# 2. Usar un LLM más avanzado que ``llama3.2``, que sea capaz de asignar pesos dinámicos a las queries.
# 3. Usar dicho LLM para "mejorar" la query y que se parezca más a una sinopsis, mecionando géneros esperados.
# 4. Cambiar algunas componentes o hiperparametros de BERTopic podría mejorar su performance.
#
#
# ## Conclusión final
#
# Embeddings densos superan a topic modeling en este problema, pero el desempeño general sigue siendo limitado. La mejora requiere datos más ricos y modelos más avanzados.
